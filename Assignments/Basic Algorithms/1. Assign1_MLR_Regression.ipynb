# %%
import pandas as pd

# %%
dataset=pd.read_csv("insurance_pre.csv")

# %%
dataset
# Out:
#       age     sex     bmi  children smoker      charges
# 0      19  female  27.900         0    yes  16884.92400
# 1      18    male  33.770         1     no   1725.55230
# 2      28    male  33.000         3     no   4449.46200
# 3      33    male  22.705         0     no  21984.47061
# 4      32    male  28.880         0     no   3866.85520
# ...   ...     ...     ...       ...    ...          ...
# 1333   50    male  30.970         3     no  10600.54830
# 1334   18  female  31.920         0     no   2205.98080
# 1335   18  female  36.850         0     no   1629.83350
# 1336   21  female  25.800         0     no   2007.94500
# 1337   61  female  29.070         0    yes  29141.36030
#
# [1338 rows x 6 columns]

# %%
dataset=pd.get_dummies(dataset,drop_first=True)
dataset=dataset.astype(int)
dataset
# Out:
#       age  bmi  children  charges  sex_male  smoker_yes
# 0      19   27         0    16884         0           1
# 1      18   33         1     1725         1           0
# 2      28   33         3     4449         1           0
# 3      33   22         0    21984         1           0
# 4      32   28         0     3866         1           0
# ...   ...  ...       ...      ...       ...         ...
# 1333   50   30         3    10600         1           0
# 1334   18   31         0     2205         0           0
# 1335   18   36         0     1629         0           0
# 1336   21   25         0     2007         0           0
# 1337   61   29         0    29141         0           1
#
# [1338 rows x 6 columns]

# %%
dataset.columns
# Out:
# Index(['age', 'bmi', 'children', 'charges', 'sex_male', 'smoker_yes'], dtype='object')

# %%
dependent=dataset[["charges"]]
dependent
# Out:
#       charges
# 0       16884
# 1        1725
# 2        4449
# 3       21984
# 4        3866
# ...       ...
# 1333    10600
# 1334     2205
# 1335     1629
# 1336     2007
# 1337    29141
#
# [1338 rows x 1 columns]

# %%
independent=dataset[['age', 'bmi', 'children', 'sex_male', 'smoker_yes']]
independent
# Out:
#       age  bmi  children  sex_male  smoker_yes
# 0      19   27         0         0           1
# 1      18   33         1         1           0
# 2      28   33         3         1           0
# 3      33   22         0         1           0
# 4      32   28         0         1           0
# ...   ...  ...       ...       ...         ...
# 1333   50   30         3         1           0
# 1334   18   31         0         0           0
# 1335   18   36         0         0           0
# 1336   21   25         0         0           0
# 1337   61   29         0         0           1
#
# [1338 rows x 5 columns]

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, Y_train, Y_test=train_test_split(independent, dependent, test_size=0.20, random_state=0)

# %%
from sklearn.linear_model import LinearRegression
regressor=LinearRegression()
regressor.fit(X_train, Y_train)
# Out:
# LinearRegression()

# %%
weight=regressor.coef_
weight
# Out:
# array([[  255.00393413,   319.72092521,   434.84826239,   -24.03756306,
#         23600.10822772]])

# %%
bias=regressor.intercept_
bias
# Out:
# array([-11723.1972154])

# %%
Y_Pred=regressor.predict(X_test)
Y_Pred
# Out:
# array([[11539.44581528],
#        [ 9968.74278246],
#        [37751.59582096],
#        [15957.40036179],
#        [ 7036.98007928],
#        [ 3637.03841156],
#        [ 1179.61765452],
#        [14096.50152026],
#        [ 8863.12482524],
#        [ 7373.78064844],
#        [ 4326.17891137],
#        [10209.44007162],
#        [ 8948.72704592],
#        [ 4365.23481612],
#        [27690.16557682],
#        [11283.73018443],
#        [11226.3034747 ],
#        [ 5548.7853782 ],
#        [ 8084.51807457],
#        [26544.57988829],
#        [33401.07281999],
#        [13977.51015291],
#        [11128.63511595],
#        [32494.56089736],
#        [ 4413.64230448],
#        [ 8677.41360906],
#        [  852.16866897],
#        [10332.29546914],
#        [ 4174.94787306],
#        [10189.26653873],
#        [ 8733.69084308],
#        [40441.51175927],
#        [15892.68337072],
#        [14107.65583177],
#        [24391.42393578],
#        [ 4559.38578935],
#        [13002.03787455],
# ...

# %%
from sklearn.metrics import r2_score
r_score=r2_score(Y_test, Y_Pred)
r_score
# Out:
# 0.7974504524086945

# %%
import pickle
filename="finalized_MLR_Assignment.sav"
pickle.dump(regressor, open(filename,'wb'))

# %%
loaded_model=pickle.load(open("finalized_MLR_Assignment.sav",'rb'))
result=loaded_model.predict([[40,30,2,1,1]])
#result=loaded_model.predict([[1,21,3,0,0]])
# Out:
# C:\Anaconda3\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(

# %%
result
# Out:
# array([[32514.35509577]])

# %%
loaded_model=pickle.load(open("finalized_MLR_Assignment.sav",'rb'))
result=loaded_model.predict([[52,30.2,1,1,0]])
result
# Out:
# C:\Anaconda3\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([[11603.39000032]])

# %%
X_test, Y_test, Y_Pred
# Out:
# (      age  bmi  children  sex_male  smoker_yes
#  578    52   30         1         1           0
#  610    47   29         1         0           0
#  569    48   40         2         1           1
#  1034   61   38         0         1           0
#  198    51   18         0         0           0
#  ...   ...  ...       ...       ...         ...
#  1084   62   30         2         0           0
#  726    41   28         1         1           0
#  1132   57   40         0         1           0
#  725    30   39         3         0           1
#  963    46   24         3         1           0
#
#  [268 rows x 5 columns],
#        charges
#  578      9724
#  610      8547
#  569     45702
#  1034    12950
#  198      9644
#  ...       ...
#  1084    15019
#  726      6664
#  1132    20709
#  725     40932
#  963      9500
#
#  [268 rows x 1 columns],
#  array([[11539.44581528],
#         [ 9968.74278246],
#         [37751.59582096],
#         [15957.40036179],
# ...

# %%
dataset.columns
# Out:
# Index(['age', 'bmi', 'children', 'charges', 'sex_male', 'smoker_yes'], dtype='object')
