# %% [markdown]
# NOTE:
# 1. When preparing the deployment file for predictions, ensure that the preprocessing code (e.g., sc) is included.
# 2. The deployment file will not perform any model training, since the model has already been trained and tested using SVM regression algorithm which is dumped into the file "finalized_model_svr.sav" .
# 3. The purpose of the deployment file is solely to preprocess user input before prediction. This ensures that the saved model (finalized_model_svr.sav) receives properly formatted data and generates the correct output.

# %%
import pickle

# %%
import pandas as pd

# %%
# Read the dataset
dataset=pd.read_csv("insurance_pre.csv")

# %%
dataset=pd.get_dummies(dataset,drop_first=True)
dataset=dataset.astype(int)

# %%
independent=dataset[['age', 'bmi', 'children', 'sex_male', 'smoker_yes']]
dependent=dataset[["charges"]]

# %%
# Split training and test data
from sklearn.model_selection import train_test_split
X_train, X_test, Y_train, Y_test=train_test_split(independent, dependent, test_size=0.20, random_state=0)

# %%
# Applying standardization (preprocessing) for input training and test data
from sklearn.preprocessing import StandardScaler
sc=StandardScaler()
X_train_pre=sc.fit_transform(X_train) 
X_test_pre=sc.transform(X_test)

# %%
preinput=sc.transform([[52,30.2,1,1,0]])
# Out:
# C:\Anaconda3\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(

# %%
loaded_model=pickle.load(open("finalized_model_svr.sav",'rb'))
result=loaded_model.predict(preinput)
result # Output as non-preprocessed data
# Out:
# array([10185.15295002])
