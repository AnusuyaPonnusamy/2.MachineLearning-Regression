# %%
import pandas as pd
dataset=pd.read_csv("insurance_pre.csv")

# %%
dataset.columns
# Out:
# Index(['age', 'sex', 'bmi', 'children', 'smoker', 'charges'], dtype='object')

# %%
dataset=pd.get_dummies(dataset, drop_first=True)
dataset=dataset.astype(int)
dataset
# Out:
#       age  bmi  children  charges  sex_male  smoker_yes
# 0      19   27         0    16884         0           1
# 1      18   33         1     1725         1           0
# 2      28   33         3     4449         1           0
# 3      33   22         0    21984         1           0
# 4      32   28         0     3866         1           0
# ...   ...  ...       ...      ...       ...         ...
# 1333   50   30         3    10600         1           0
# 1334   18   31         0     2205         0           0
# 1335   18   36         0     1629         0           0
# 1336   21   25         0     2007         0           0
# 1337   61   29         0    29141         0           1
#
# [1338 rows x 6 columns]

# %%
independent=dataset[['age', 'bmi', 'children', 'sex_male', 'smoker_yes']]
independent
# Out:
#       age  bmi  children  sex_male  smoker_yes
# 0      19   27         0         0           1
# 1      18   33         1         1           0
# 2      28   33         3         1           0
# 3      33   22         0         1           0
# 4      32   28         0         1           0
# ...   ...  ...       ...       ...         ...
# 1333   50   30         3         1           0
# 1334   18   31         0         0           0
# 1335   18   36         0         0           0
# 1336   21   25         0         0           0
# 1337   61   29         0         0           1
#
# [1338 rows x 5 columns]

# %%
dependent=dataset[['charges']]
dependent
# Out:
#       charges
# 0       16884
# 1        1725
# 2        4449
# 3       21984
# 4        3866
# ...       ...
# 1333    10600
# 1334     2205
# 1335     1629
# 1336     2007
# 1337    29141
#
# [1338 rows x 1 columns]

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, Y_train, Y_test = train_test_split(independent, dependent, test_size=0.30, random_state=0)

# %%
from sklearn.ensemble import AdaBoostRegressor
regressor=AdaBoostRegressor(estimator=None, n_estimators=2)
regressor=regressor.fit(X_train, Y_train)
regressor
# Out:
# C:\Anaconda3\Lib\site-packages\sklearn\utils\validation.py:1406: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# AdaBoostRegressor(n_estimators=2)

# %%
Y_pred=regressor.predict(X_test)

# %%
from sklearn.metrics import r2_score
r_score=r2_score(Y_test, Y_pred)
r_score
# Out:
# 0.8740167817941462

# %%
# estimator=None, n_estimators=50, learning_rate=10.0, loss='exponential', random_state=None

# %%
#regressor=AdaBoostRegressor(n_estimators=50, learning_rate=10.0, random_state=None)
#regressor=regressor.fit(X_train, Y_train)
#regressor

# %%
#r_score=r2_score(Y_test, Y_pred)
#r_score

# %%
import pickle
filename="insurance_pre_AdaBoost.sav"
pickle.dump(regressor, open(filename,'wb'))

# %%
loaded_model=pickle.load(open("insurance_pre_AdaBoost.sav",'rb'))
result=loaded_model.predict([[52,30,1,1,0]])
result
# Out:
# C:\Anaconda3\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but AdaBoostRegressor was fitted with feature names
#   warnings.warn(
# array([14057.3030303])

# %%
X_test, Y_test, Y_pred
# Out:
# (      age  bmi  children  sex_male  smoker_yes
#  578    52   30         1         1           0
#  610    47   29         1         0           0
#  569    48   40         2         1           1
#  1034   61   38         0         1           0
#  198    51   18         0         0           0
#  ...   ...  ...       ...       ...         ...
#  1261   28   37         1         1           0
#  494    21   25         4         1           1
#  97     55   38         0         1           0
#  418    64   39         1         1           0
#  920    62   25         0         0           0
#
#  [402 rows x 5 columns],
#        charges
#  578      9724
#  610      8547
#  569     45702
#  1034    12950
#  198      9644
#  ...       ...
#  1261     3277
#  494     17942
#  97      10226
#  418     14418
#  920     13451
#
#  [402 rows x 1 columns],
#  array([14622.03370787, 11483.01369863, 46400.79411765, 14178.41721854,
# ...

# %%
dataset
# Out:
#       age  bmi  children  charges  sex_male  smoker_yes
# 0      19   27         0    16884         0           1
# 1      18   33         1     1725         1           0
# 2      28   33         3     4449         1           0
# 3      33   22         0    21984         1           0
# 4      32   28         0     3866         1           0
# ...   ...  ...       ...      ...       ...         ...
# 1333   50   30         3    10600         1           0
# 1334   18   31         0     2205         0           0
# 1335   18   36         0     1629         0           0
# 1336   21   25         0     2007         0           0
# 1337   61   29         0    29141         0           1
#
# [1338 rows x 6 columns]

# %%
estimator=regressor.estimator_
estimator
# Out:
# DecisionTreeRegressor(max_depth=3)

# %%
estimators=regressor.estimators_
estimators
# Out:
# [DecisionTreeRegressor(max_depth=3, random_state=1213879563),
#  DecisionTreeRegressor(max_depth=3, random_state=36185339)]

# %%
estimator_errors=regressor.estimator_errors_ # Regression error for each estimator in the boosted ensemble.
estimator_errors
# Out:
# array([0.11892565, 0.23478958])

# %%
n_features_in=regressor.n_features_in_ # Number of features seen during fit.
n_features_in
# Out:
# 5

# %%
feature_names_in=regressor.feature_names_in_ # Names of features seen during fit. Defined only when X has feature names that are all strings.
feature_names_in
# Out:
# array(['age', 'bmi', 'children', 'sex_male', 'smoker_yes'], dtype=object)
